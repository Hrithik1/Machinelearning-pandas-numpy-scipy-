# %% [markdown]
# # Standard Deviation & Variance

# %%
import numpy as np
import matplotlib.pyplot as plt

income=np.random.normal(40,50,100)

plt.hist(income,50)
plt.show()

# %%
income.std()
# Out:
# 49.61924380015695

# %%
income.var()
# Out:
# 2462.0693552994144

# %% [markdown]
# # Uniform Diatribution

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.random.uniform(10,20,10000)

plt.hist(a,50)
plt.show()

# %% [markdown]
# # Normal/Gaussian Distribution

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

a=np.arange(-3,3,0.5)
plt.plot(a,norm.pdf(a))
