# %% [markdown]
# # Standard Deviation & Variance

# %%
import numpy as np
import matplotlib.pyplot as plt

income=np.random.normal(40,50,100)

plt.hist(income,50)
plt.show()

# %%
income.std()
# Out:
# 49.61924380015695

# %%
income.var()
# Out:
# 2462.0693552994144

# %% [markdown]
# # Uniform Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.random.uniform(-20,20,100000)

plt.hist(a,50)
plt.show()

# %% [markdown]
# # Normal/Gaussian Distribution

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
a=np.arange(-3,3,0.005)
plt.plot(a,norm.pdf(a))

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
a=np.arange(-1,1,.0005)
plt.plot(a,norm.pdf(a)) #plt.plot(x,y) x and y axis

# %%
from scipy.stats import expon
a=np.arange(-10,10,0.001)
c=plt.plot(a,expon.pdf(a))
b=np.arange(1,10,0.001)
d=plt.plot(b,expon.pdf(b))

print(c,d)
# Out:
# [<matplotlib.lines.Line2D object at 0x7fc3320739a0>] [<matplotlib.lines.Line2D object at 0x7fc332073b50>]

# %%
z=np.random.normal(300,2,1000)
plt.hist(z,50)
plt.show()

# %%
from scipy.stats import binom
a=np.arange(0,10,.1)
plt.plot(a,binom.pmf(a,10,.5))

# %%
from scipy.stats import poisson

a=np.arange(1000,2000,.5)
plt.plot(a,poisson.pmf(a,1400))
